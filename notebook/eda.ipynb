# %%
import xarray as xr

# %%
d = xr.load_dataset("waves_2019-01-01.nc")

# %%
d
# Out:
# <xarray.Dataset> Size: 180MB
# Dimensions:    (longitude: 720, latitude: 261, time: 24)
# Coordinates:
#   * longitude  (longitude) float32 3kB -180.0 -179.5 -179.0 ... 179.0 179.5
#   * latitude   (latitude) float32 1kB 70.0 69.5 69.0 68.5 ... -59.0 -59.5 -60.0
#   * time       (time) datetime64[ns] 192B 2019-01-01 ... 2019-01-01T23:00:00
# Data variables:
#     hmax       (time, latitude, longitude) float64 36MB nan nan ... 6.071 6.262
#     mwd        (time, latitude, longitude) float64 36MB nan nan ... 4.62 7.268
#     mwp        (time, latitude, longitude) float64 36MB nan nan ... 7.129 7.06
#     tmax       (time, latitude, longitude) float64 36MB nan nan ... 6.515 6.458
#     swh        (time, latitude, longitude) float64 36MB nan nan ... 3.145 3.231
# Attributes:
#     Conventions:  CF-1.6
#     history:      2020-06-14 14:39:51 GMT by grib_to_netcdf-2.16.0: /opt/ecmw...

# %%
hmax_overall = d.max(dim="time")["hmax"]

# %%
hmax_overall.plot()

# %%
hmax_overall.sel(latitude=0.0, longitude=0.0)
# Out:
# <xarray.DataArray 'hmax' ()> Size: 8B
# array(2.32598995)
# Coordinates:
#     longitude  float32 4B 0.0
#     latitude   float32 4B 0.0
